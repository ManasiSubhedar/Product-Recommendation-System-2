# %% [markdown]
# ## Task 1-Load and understand the dataset

# %% [markdown]
# # Part 1-Data preprocessing

# %%
import pandas as pd
import spacy
import re
import sklearn

# %%
df=pd.read_csv('products_dataset.csv')

# %%
df.head()
# Out:
#    Unnamed: 0          ID  ProdID  Rating  ReviewCount  \
# 0           0  1705736792       2     0.0          0.0
# 1           1          95      76     0.0          0.0
# 2           2           8       8     4.5      29221.0
# 3           3           4       3     0.0          0.0
# 4           4         990       3     0.0        131.0
#
#                                             Category             Brand  \
# 0  premium, beauty, premium, makeup, premium, nai...               opi
# 1  beauty, hair, care, hair, color, auburn, hair,...              easy
# 2  beauty, hair, care, hair, color, permanent, ha...           clairol
# 3                                beauty, makeup, lip  kokie, cosmetics
# 4  seasonal, stock, essentials, personal, care, s...          gillette
#
#                                                 Name  \
# 0  OPI Infinite Shine, Nail Lacquer Nail Polish, ...
# 1  Nice n Easy Permanent Color, 111 Natural Mediu...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4090 entries, 0 to 4089
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   4090 non-null   int64
#  1   ID           4090 non-null   int64
#  2   ProdID       4090 non-null   int64
#  3   Rating       4090 non-null   float64
#  4   ReviewCount  4090 non-null   float64
#  5   Category     4081 non-null   object
#  6   Brand        3994 non-null   object
#  7   Name         4090 non-null   object
#  8   ImageURL     4090 non-null   object
#  9   Description  3174 non-null   object
#  10  Tags         4090 non-null   object
# dtypes: float64(2), int64(3), object(6)
# memory usage: 351.6+ KB

# %%
df=df.drop(columns=['Unnamed: 0','ID','ProdID','Rating','ReviewCount','ImageURL'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4090 entries, 0 to 4089
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Category     4081 non-null   object
#  1   Brand        3994 non-null   object
#  2   Name         4090 non-null   object
#  3   Description  3174 non-null   object
#  4   Tags         4090 non-null   object
# dtypes: object(5)
# memory usage: 159.9+ KB

# %% [markdown]
# ## Task 2-Text preprocessing for recommendation

# %%
df['Brand'].isnull().sum()
# Out:
# np.int64(96)

# %%
df['Category'].isnull().sum()
# Out:
# np.int64(9)

# %%
df['Name'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Description'].isnull().sum()
# Out:
# np.int64(916)

# %%
df['Tags'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Brand']=df['Brand'].fillna("")
df['Category']=df['Category'].fillna("")
df['Description']=df['Description'].fillna("")

# %%
df['Brand'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Category'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Description'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['text']=df['Name']+df['Category']+df['Brand']+df['Description']+df['Tags']

# %%
df['Name'][0]
# Out:
# 'OPI Infinite Shine, Nail Lacquer Nail Polish, Bubble Bath'

# %%
df['text']
# Out:
# 0       OPI Infinite Shine, Nail Lacquer Nail Polish, ...
# 1       Nice n Easy Permanent Color, 111 Natural Mediu...
# 2       Clairol Nice N Easy Permanent Color 7/106A Nat...
# 3       Kokie Professional Matte Lipstick, Hot Berry, ...
# 4       Gillette TRAC II Plus Razor Blade Refills, Fit...
#                               ...
# 4085    LivDry Incontinence Pad Insert for Men and Wom...
# 4086    Pet Dog Cat Warm Coat Knit Sweater Winter Clot...
# 4087    Pure Gold Bitter Orange Essential Oil, 100% Na...
# 4088    Garden Mint Room Spray (Double Strength), 4 ou...
# 4089    Nail File Electric Drill, 6 in 1 Professional ...
# Name: text, Length: 4090, dtype: object

# %%
def preprocess(text):
    text=text.lower()
    text=re.sub()
